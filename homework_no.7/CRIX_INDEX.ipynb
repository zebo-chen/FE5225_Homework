# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
# crix daily data
with open("./crix.json") as f:
    result=json.load(f)
    #print(result)
    crix_daily = pd.DataFrame(result)
crix_daily
# Out:
#             date          price
# 0     2014-07-31    1000.000000
# 1     2014-08-01    1018.202717
# 2     2014-08-02    1008.772389
# 3     2014-08-03    1004.416500
# 4     2014-08-04    1004.984138
# 5     2014-08-05     998.041056
# 6     2014-08-06     999.866318
# 7     2014-08-07    1006.144005
# 8     2014-08-08    1012.505635
# 9     2014-08-09    1006.846193
# 10    2014-08-10    1006.865040
# 11    2014-08-11     980.933122
# 12    2014-08-12     970.507694
# 13    2014-08-13     930.476552
# 14    2014-08-14     862.782202
# 15    2014-08-15     843.515369
# 16    2014-08-16     891.020720
# 17    2014-08-17     846.518078
# 18    2014-08-18     786.492155
# 19    2014-08-19     829.440617
# 20    2014-08-20     880.501096
# 21    2014-08-21     882.297949
# 22    2014-08-22     882.556600
# 23    2014-08-23     849.458735
# 24    2014-08-24     869.340921
# 25    2014-08-25     855.783393
# 26    2014-08-26     872.978086
# 27    2014-08-27     872.512855
# ...

# %%
crix_daily.plot()

# %%
# crix high fluency data
with open("./crix_hf.json") as f:
    result=json.load(f)
    #print(result)
    crix_hf = pd.DataFrame(result)
crix_hf
# Out:
#                     date          price
# 0    2021-03-19 16:15:58  164012.176609
# 1    2021-03-19 16:21:53  163338.562105
# 2    2021-03-19 16:25:26  163338.562105
# 3    2021-03-19 16:31:53  164293.816241
# 4    2021-03-19 16:35:31  164293.816241
# 5    2021-03-19 16:41:43  164269.022036
# 6    2021-03-19 16:45:15  164269.022036
# 7    2021-03-19 16:52:39  164965.204782
# 8    2021-03-19 16:55:52  164976.261395
# 9    2021-03-19 17:01:18  164976.261395
# 10   2021-03-19 17:07:28  165034.031704
# 11   2021-03-19 17:10:28  165034.031704
# 12   2021-03-19 17:17:41  164786.200632
# 13   2021-03-19 17:20:28  164786.200632
# 14   2021-03-19 17:26:47  164404.566589
# 15   2021-03-19 17:30:40  164404.566589
# 16   2021-03-19 17:37:01  164338.193188
# 17   2021-03-19 17:40:27  164338.193188
# 18   2021-03-19 17:47:30  164337.751752
# 19   2021-03-19 17:50:40  164337.751752
# 20   2021-03-19 17:56:42  164778.382069
# 21   2021-03-19 18:03:38  164778.382069
# ...

# %%
crix_hf.plot()

# %%
# crix 11 data
with open("./crix11.json") as f:
    result=json.load(f)
    #print(result)
    crix_vcrix = pd.DataFrame(result)
crix_vcrix
# Out:
#             date     n      vcrix
# 0     2014-11-28     1  1000.0000
# 1     2014-11-29     2   965.9799
# 2     2014-11-30     3   959.5944
# 3     2014-12-01     4   959.5944
# 4     2014-12-02     5   934.6433
# 5     2014-12-03     6   931.8952
# 6     2014-12-04     7   934.8070
# 7     2014-12-05     8   934.4990
# 8     2014-12-06     9   927.9591
# 9     2014-12-07    10   918.9630
# 10    2014-12-08    11   914.2787
# 11    2014-12-09    12   940.8617
# 12    2014-12-10    13   912.1438
# 13    2014-12-11    14   913.6096
# 14    2014-12-12    15   916.6603
# 15    2014-12-13    16   660.5024
# 16    2014-12-14    17   665.1506
# 17    2014-12-15    18   634.7525
# 18    2014-12-16    19   600.8300
# 19    2014-12-17    20   600.0275
# 20    2014-12-18    21   603.6457
# 21    2014-12-19    22   593.7620
# 22    2014-12-20    23   597.8804
# 23    2014-12-21    24   550.4552
# 24    2014-12-22    25   567.0554
# 25    2014-12-23    26   612.8725
# ...

# %%
crix_vcrix.plot()
